# %% [markdown]
# # XY-MODEL
# Monte Carlo simulation on 2D XY-model
#
# Metropolis algorithm is applyed in the simulation.
#
# Using this program, you can show the envolotion of 2D spin system at given temperature.
#
# Simulated Annealing is also applied to show the thermal observables versus temperature.
#
# For more detail, see the comments in the .py file.

# %%
import XY_model as xy

# %%
xy.visulizeXY_equ(T=0.5,L=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-066c07eec6ed> in <module>
# ----> 1 xy.visulizeXY_equ(T=0.5,L=20)
#
# ~/Documents/GitHub/XY-MODEL/XY_model.py in visulizeXY_equ(T, L)
#     177     nsweeps=1000
#     178     magnetization=[]
# --> 179     stime=list(range(nsweeps))
#     180     for k in stime:
#     181         S=sweep(T,S,H=None)
#
# ~/Documents/GitHub/XY-MODEL/XY_model.py in visulize(S, T, i)
#     150     plt.figure(1,figsize=(8,8), dpi=100)
#     151     #plt.title('Arrows scale with plot width, not view')
# --> 152     Q = plt.quiver(X, Y, U, V, units='width')
#     153     qk = plt.quiverkey(Q, 0.1, 0.1, 1, r'$2 \frac{m}{s}$', labelpos='E',
#     154                    coordinates='figure')
#
# TypeError: %i format: a number is required, not NoneType

# %%
xy.cooling(10)
# Out:
# ([-0.40485973733754593,
#   -0.40479135852550535,
#   -0.4105764433655925,
#   -0.4284692451638671,
#   -0.471105449102757,
#   -0.47388162111469967,
#   -0.455747184506166,
#   -0.5173637834148352,
#   -0.5369301458709085,
#   -0.5123621002981144,
#   -0.5542104164352324,
#   -0.5334468351584474,
#   -0.5249300488971806,
#   -0.6730840619304135,
#   -0.6292401591166324,
#   -0.621360833343521,
#   -0.6394037777394272,
#   -0.7083570411660056,
#   -0.770106273427739,
#   -0.7525472201653757,
#   -0.8068502823855747,
#   -0.8737441277055273,
#   -0.8012832573916211,
#   -1.021339474474113,
#   -1.0428161343771982,
#   -1.0471216820588105,
#   -1.0489049473215677,
#   -1.244162534162821,
#   -1.2799668738363594,
#   -1.3447148639620168,
#   -1.3619558860828704,
#   -1.410292326039575,
#   -1.4881983193662642,
#   -1.5175190089136772,
#   -1.5689433670161126,
#   -1.5910918069996292,
#   -1.60665008653634,
#   -1.638753125119485,
#   -1.6877605714200248,
#   -1.7213781404561432,
#   -1.7457060629183,
#   -1.778413609356623,
#   -1.807908775884266,
#   -1.832431093446965,
#   -1.8622401234993808,
#   -1.892111216508137,
#   -1.9194331216901015,
#   -1.9439494374199182,
#   -1.9691329368486707,
